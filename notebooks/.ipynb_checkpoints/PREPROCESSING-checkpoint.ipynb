# %%
## CLEANING AND PROCESSING OUR DATA
import pandas as pd
## data import
train = pd.read_csv("../data/raw/Train.csv")
test = pd.read_csv("../data/raw/Test.csv")
var_defs = pd.read_csv("../data/raw/VariableDefinitions.csv")

# %%
## Cleaning our training data

# %%
before  = train.shape[0]

# %%
new_train = train.dropna()

# %%
after = new_train.shape[0]

# %%
print(f"Number of dropped rows : {before - after}\nBefore : {before}\nAfter : {after}")
# Out:
# Number of dropped rows : 1082
# Before : 18506
# After : 17424

# %%
## Cleaning our training data

# %%
before = test.shape[0]
new_test = test.dropna()
after = new_test.shape[0]
print(f"Number of dropped rows : {before - after}\nBefore : {before}\nAfter : {after}")
# Out:
# Number of dropped rows : 364
# Before : 6169
# After : 5805

# %%
## saving our data
train.to_csv("../data/processed/Cleaned_train.csv",index = False)
test.to_csv("../data/processed/Cleaned_test.csv",index = False)
